# %% [markdown]
# # IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # DATA LOADING

# %%
train = pd.read_csv('train (1).csv')
test = pd.read_csv('test (1).csv')
sub  = pd.read_csv('SampleSubmission.csv')

# %%
train.head
# Out:
# <bound method NDFrame.head of      Item_ID      Store_ID       Item_Store_ID  Item_Weight  \
# 0      DRA12  BABATUNJI010  DRA12_BABATUNJI010        11.60
# 1      DRA12  BABATUNJI013  DRA12_BABATUNJI013        11.60
# 2      DRA12  BABATUNJI017  DRA12_BABATUNJI017        11.60
# 3      DRA12  BABATUNJI018  DRA12_BABATUNJI018        11.60
# 4      DRA12  BABATUNJI035  DRA12_BABATUNJI035        11.60
# ...      ...           ...                 ...          ...
# 4985   NCZ54  BABATUNJI019  NCZ54_BABATUNJI019          NaN
# 4986   NCZ54  BABATUNJI027  NCZ54_BABATUNJI027          NaN
# 4987   NCZ54  BABATUNJI045  NCZ54_BABATUNJI045        14.65
# 4988   NCZ54  BABATUNJI046  NCZ54_BABATUNJI046        14.65
# 4989   NCZ54  BABATUNJI049  NCZ54_BABATUNJI049        14.65
#
#      Item_Sugar_Content  Item_Visibility    Item_Type  Item_Price  \
# 0             Low Sugar         0.068535  Soft Drinks      357.54
# 1             Low Sugar         0.040912  Soft Drinks      355.79
# ...

# %%
test.head
# Out:
# <bound method NDFrame.head of      Item_ID      Store_ID       Item_Store_ID  Item_Weight  \
# 0      DRA59  BABATUNJI010  DRA59_BABATUNJI010        8.270
# 1      DRA59  BABATUNJI013  DRA59_BABATUNJI013        8.270
# 2      DRB01  BABATUNJI013  DRB01_BABATUNJI013        7.390
# 3      DRB13  BABATUNJI010  DRB13_BABATUNJI010        6.115
# 4      DRB13  BABATUNJI013  DRB13_BABATUNJI013        6.115
# ...      ...           ...                 ...          ...
# 3527   NCZ42  BABATUNJI010  NCZ42_BABATUNJI010       10.500
# 3528   NCZ42  BABATUNJI013  NCZ42_BABATUNJI013       10.500
# 3529   NCZ42  BABATUNJI049  NCZ42_BABATUNJI049       10.500
# 3530   NCZ53  BABATUNJI010  NCZ53_BABATUNJI010        9.600
# 3531   NCZ53  BABATUNJI013  NCZ53_BABATUNJI013        9.600
#
#      Item_Sugar_Content  Item_Visibility           Item_Type  Item_Price  \
# 0          Normal Sugar         0.214125         Soft Drinks      459.98
# ...

# %%
train.shape
# Out:
# (4990, 13)

# %%
test.shape
# Out:
# (3532, 12)

# %%
train.describe(include='all')
# Out:
#        Item_ID      Store_ID       Item_Store_ID  Item_Weight  \
# count     4990          4990                4990  4188.000000
# unique    1451            10                4990          NaN
# top      DRE49  BABATUNJI049  FDX09_BABATUNJI035          NaN
# freq         9           620                   1          NaN
# mean       NaN           NaN                 NaN    12.908838
# std        NaN           NaN                 NaN     4.703256
# min        NaN           NaN                 NaN     4.555000
# 25%        NaN           NaN                 NaN     8.767500
# 50%        NaN           NaN                 NaN    12.600000
# 75%        NaN           NaN                 NaN    17.100000
# max        NaN           NaN                 NaN    21.350000
#
#        Item_Sugar_Content  Item_Visibility    Item_Type   Item_Price  \
# count                4990      4990.000000         4990  4990.000000
# unique                  3              NaN           16          NaN
# ...

# %%
test.describe(include='all')
# Out:
#        Item_ID      Store_ID       Item_Store_ID  Item_Weight  \
# count     3532          3532                3532  2871.000000
# unique    1207            10                3532          NaN
# top      FDH33  BABATUNJI027  FDV07_BABATUNJI027          NaN
# freq         8           473                   1          NaN
# mean       NaN           NaN                 NaN    12.781665
# std        NaN           NaN                 NaN     4.554868
# min        NaN           NaN                 NaN     4.555000
# 25%        NaN           NaN                 NaN     8.840000
# 50%        NaN           NaN                 NaN    12.600000
# 75%        NaN           NaN                 NaN    16.600000
# max        NaN           NaN                 NaN    21.350000
#
#        Item_Sugar_Content  Item_Visibility              Item_Type  \
# count                3532      3532.000000                   3532
# unique                  3              NaN                     16
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4990 entries, 0 to 4989
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Item_ID              4990 non-null   object
#  1   Store_ID             4990 non-null   object
#  2   Item_Store_ID        4990 non-null   object
#  3   Item_Weight          4188 non-null   float64
#  4   Item_Sugar_Content   4990 non-null   object
#  5   Item_Visibility      4990 non-null   float64
#  6   Item_Type            4990 non-null   object
#  7   Item_Price           4990 non-null   float64
#  8   Store_Start_Year     4990 non-null   int64
#  9   Store_Size           3540 non-null   object
#  10  Store_Location_Type  4990 non-null   object
#  11  Store_Type           4990 non-null   object
#  12  Item_Store_Returns   4990 non-null   float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 506.9+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3532 entries, 0 to 3531
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Item_ID              3532 non-null   object
#  1   Store_ID             3532 non-null   object
#  2   Item_Store_ID        3532 non-null   object
#  3   Item_Weight          2871 non-null   float64
#  4   Item_Sugar_Content   3532 non-null   object
#  5   Item_Visibility      3532 non-null   float64
#  6   Item_Type            3532 non-null   object
#  7   Item_Price           3532 non-null   float64
#  8   Store_Start_Year     3532 non-null   int64
#  9   Store_Size           2573 non-null   object
#  10  Store_Location_Type  3532 non-null   object
#  11  Store_Type           3532 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 331.2+ KB

# %%
train.isnull().sum()
# Out:
# Item_ID                   0
# Store_ID                  0
# Item_Store_ID             0
# Item_Weight             802
# Item_Sugar_Content        0
# Item_Visibility           0
# Item_Type                 0
# Item_Price                0
# Store_Start_Year          0
# Store_Size             1450
# Store_Location_Type       0
# Store_Type                0
# Item_Store_Returns        0
# dtype: int64

# %%
train['Store_Size'].fillna('Medium',inplace=True)

# %%
train['Item_Weight'].fillna(12.781665,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
IbI = LabelEncoder()
train['Store_Size']=IbI.fit_transform (train['Store_Size'])
train['Item_Sugar_Content']=IbI.fit_transform (train['Item_Sugar_Content'])

# %%
train['Store_Type'].unique()
# Out:
# array(['Grocery Store', 'Supermarket Type1', 'Supermarket Type2',
#        'Supermarket Type3'], dtype=object)

# %%
train['Item_Type'].unique()
# Out:
# array(['Soft Drinks', 'Dairy', 'Hard Drinks', 'Canned', 'Frozen Foods',
#        'Fruits and Vegetables', 'Snack Foods', 'Baking Goods',
#        'Starchy Foods', 'Meat', 'Seafood', 'Breakfast', 'Breads',
#        'Health and Hygiene', 'Household', 'Others'], dtype=object)

# %%
left = pd.get_dummies(train[['Item_Type','Store_Location_Type','Store_Type']])
train = train.join(left)

# %%
train.head()
# Out:
#   Item_ID      Store_ID       Item_Store_ID  Item_Weight  Item_Sugar_Content  \
# 0   DRA12  BABATUNJI010  DRA12_BABATUNJI010         11.6                   0
# 1   DRA12  BABATUNJI013  DRA12_BABATUNJI013         11.6                   0
# 2   DRA12  BABATUNJI017  DRA12_BABATUNJI017         11.6                   0
# 3   DRA12  BABATUNJI018  DRA12_BABATUNJI018         11.6                   0
# 4   DRA12  BABATUNJI035  DRA12_BABATUNJI035         11.6                   2
#
#    Item_Visibility    Item_Type  Item_Price  Store_Start_Year  Store_Size  \
# 0         0.068535  Soft Drinks      357.54              2005           1
# 1         0.040912  Soft Drinks      355.79              1994           0
# 2         0.041178  Soft Drinks      350.79              2014           1
# 3         0.041113  Soft Drinks      355.04              2016           1
# 4         0.000000  Soft Drinks      354.79              2011           2
#
# ...

# %%
to_drop=['Item_Type','Store_Location_Type','Store_Type']
train.drop(to_drop,inplace=True,axis=1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4990 entries, 0 to 4989
# Data columns (total 33 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Item_ID                          4990 non-null   object
#  1   Store_ID                         4990 non-null   object
#  2   Item_Store_ID                    4990 non-null   object
#  3   Item_Weight                      4990 non-null   float64
#  4   Item_Sugar_Content               4990 non-null   int32
#  5   Item_Visibility                  4990 non-null   float64
#  6   Item_Price                       4990 non-null   float64
#  7   Store_Start_Year                 4990 non-null   int64
#  8   Store_Size                       4990 non-null   int32
#  9   Item_Store_Returns               4990 non-null   float64
#  10  Item_Type_Baking Goods           4990 non-null   uint8
#  11  Item_Type_Breads                 4990 non-null   uint8
# ...

# %%
 test.isnull().sum()
# Out:
# Item_ID                  0
# Store_ID                 0
# Item_Store_ID            0
# Item_Weight            661
# Item_Sugar_Content       0
# Item_Visibility          0
# Item_Type                0
# Item_Price               0
# Store_Start_Year         0
# Store_Size             959
# Store_Location_Type      0
# Store_Type               0
# dtype: int64

# %%
test['Store_Size'].fillna('Medium',inplace=True)

# %%
test['Item_Weight'].fillna(12.781665,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
IbI = LabelEncoder()
test['Store_Size']=IbI.fit_transform (test['Store_Size'])
test['Item_Sugar_Content']=IbI.fit_transform (test['Item_Sugar_Content'])

# %%
test['Store_Type'].unique()
# Out:
# array(['Grocery Store', 'Supermarket Type1', 'Supermarket Type3',
#        'Supermarket Type2'], dtype=object)

# %%
test['Item_Type'].unique()
# Out:
# array(['Soft Drinks', 'Dairy', 'Hard Drinks', 'Canned', 'Frozen Foods',
#        'Fruits and Vegetables', 'Snack Foods', 'Baking Goods',
#        'Starchy Foods', 'Meat', 'Seafood', 'Breakfast', 'Breads',
#        'Household', 'Health and Hygiene', 'Others'], dtype=object)

# %%
left = pd.get_dummies(test[['Item_Type','Store_Location_Type','Store_Type']])
test = test.join(left)

# %%
test.head()
# Out:
#   Item_ID      Store_ID       Item_Store_ID  Item_Weight  Item_Sugar_Content  \
# 0   DRA59  BABATUNJI010  DRA59_BABATUNJI010        8.270                   1
# 1   DRA59  BABATUNJI013  DRA59_BABATUNJI013        8.270                   1
# 2   DRB01  BABATUNJI013  DRB01_BABATUNJI013        7.390                   0
# 3   DRB13  BABATUNJI010  DRB13_BABATUNJI010        6.115                   1
# 4   DRB13  BABATUNJI013  DRB13_BABATUNJI013        6.115                   1
#
#    Item_Visibility    Item_Type  Item_Price  Store_Start_Year  Store_Size  \
# 0         0.214125  Soft Drinks      459.98              2005           1
# 1         0.127821  Soft Drinks      464.98              1994           0
# 2         0.082171  Soft Drinks      477.38              1994           0
# 3         0.011791  Soft Drinks      472.63              2005           1
# 4         0.007038  Soft Drinks      473.13              1994           0
#
# ...

# %%
to_drop=['Item_ID','Store_ID','Item_Type','Store_Location_Type','Store_Type']
test.drop(to_drop,inplace=True,axis=1)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3532 entries, 0 to 3531
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Item_Store_ID                    3532 non-null   object
#  1   Item_Weight                      3532 non-null   float64
#  2   Item_Sugar_Content               3532 non-null   int32
#  3   Item_Visibility                  3532 non-null   float64
#  4   Item_Price                       3532 non-null   float64
#  5   Store_Start_Year                 3532 non-null   int64
#  6   Store_Size                       3532 non-null   int32
#  7   Item_Type_Baking Goods           3532 non-null   uint8
#  8   Item_Type_Breads                 3532 non-null   uint8
#  9   Item_Type_Breakfast              3532 non-null   uint8
#  10  Item_Type_Canned                 3532 non-null   uint8
#  11  Item_Type_Dairy                  3532 non-null   uint8
# ...

# %%
X=train.drop(['Item_ID', 'Store_ID', 'Item_Store_ID', 'Item_Store_Returns'], axis=1)
y=train['Item_Store_Returns']

print(len(X), len(y))
# Out:
# 4990 4990

# %% [markdown]
# # Baseline Model

# %%
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
lr = LinearRegression()
rf = RandomForestRegressor()

# %%
lr.fit(X_train, y_train)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred = rf.predict(X_test)
mean_squared_error(y_test,y_pred)
# Out:
# 9639928.359444309

# %%
y_prid = lr.predict(X_test)
mean_squared_error(y_test,y_prid)
# Out:
# 9014100.611400869

# %%
test_x = test.drop('Item_Store_ID', axis = 1)

# %%
prediction = lr.predict(test_x)

# %%
sub['Item_Store_Returns'] = prediction
sub.to_csv('submissionry.csv', index=False)
